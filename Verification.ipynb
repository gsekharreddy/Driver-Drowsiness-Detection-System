# %%
import sys
import torch
import cv2

print("--- SYSTEM DIAGNOSTICS ---")
print(f"Python Version: {sys.version.split()[0]} (Should be 3.10.x)")
print(f"PyTorch Version: {torch.__version__}")
print(f"CUDA Available: {torch.cuda.is_available()}")

if torch.cuda.is_available():
    print(f"GPU Detected: {torch.cuda.get_device_name(0)}")
    print("✅ STATUS: READY TO TRAIN. 🚀")
else:
    print("❌ STATUS: STILL CPU. Did you switch the Kernel in VS Code?")

try:
    print(f"OpenCV Version: {cv2.__version__}")
except ImportError:
    print("❌ OpenCV missing.")
# Out:
# --- SYSTEM DIAGNOSTICS ---
# Python Version: 3.10.19 (Should be 3.10.x)
# PyTorch Version: 2.5.1+cu121
# CUDA Available: True
# GPU Detected: NVIDIA GeForce RTX 2050
# ✅ STATUS: READY TO TRAIN. 🚀
# OpenCV Version: 4.13.0
